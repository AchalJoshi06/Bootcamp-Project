# %% [markdown]
# # Filtering And Ordering

# %%
import pandas as pd
df =pd.read_excel(r"D:\Sorting Files\Filtering&Ordering\world_population_excel_workbook.xlsx")

# %%
df
# Out:
#      Rank CCA3            Country           Capital Continent  \
# 0      36  AFG        Afghanistan             Kabul      Asia
# 1     138  ALB            Albania            Tirana    Europe
# 2      34  DZA            Algeria           Algiers    Africa
# 3     213  ASM     American Samoa         Pago Pago   Oceania
# 4     203  AND            Andorra  Andorra la Vella    Europe
# ..    ...  ...                ...               ...       ...
# 229   226  WLF  Wallis and Futuna          Mata-Utu   Oceania
# 230   172  ESH     Western Sahara         El AaiÃºn    Africa
# 231    46  YEM              Yemen             Sanaa      Asia
# 232    63  ZMB             Zambia            Lusaka    Africa
# 233    74  ZWE           Zimbabwe            Harare    Africa
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 0           41128771         38972230         33753499         28189672
# 1            2842321          2866849          2882481          2913399
# ...

# %%
df[df['Rank'] <= 10]
# Out:
#      Rank CCA3        Country           Capital      Continent  \
# 16      8  BGD     Bangladesh             Dhaka           Asia
# 27      7  BRA         Brazil          Brasilia  South America
# 41      1  CHN          China           Beijing           Asia
# 92      2  IND          India         New Delhi           Asia
# 93      4  IDN      Indonesia           Jakarta           Asia
# 131    10  MEX         Mexico       Mexico City  North America
# 149     6  NGA        Nigeria             Abuja         Africa
# 156     5  PAK       Pakistan         Islamabad           Asia
# 171     9  RUS         Russia            Moscow         Europe
# 221     3  USA  United States  Washington, D.C.  North America
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 16         171186372        167420951        157830000        148391139
# 27         215313498        213196304        205188205        196353492
# ...

# %%
specific_countries = ['Indonesia','India']

# %%
df[df['Country'].isin(specific_countries)]
# Out:
#     Rank CCA3    Country    Capital Continent  2022 Population  \
# 92     2  IND      India  New Delhi      Asia       1417173173
# 93     4  IDN  Indonesia    Jakarta      Asia        275501339
#
#     2020 Population  2015 Population  2010 Population  2000 Population  \
# 92       1396387127       1322866505       1240613620       1059633675
# 93        271857970        259091970        244016173        214072421
#
#     1990 Population  1980 Population  1970 Population  Area (kmÂ²)  \
# 92        870452165        696828385        557501301      3287590
# 93        182159874        148177096        115228394      1904569
#
#     Density (per kmÂ²)  Growth Rate  World Population Percentage
# 92            431.0675       1.0068                        17.77
# 93            144.6529       1.0064                         3.45

# %%
df[df['Country'].str.contains('kistan')]
# Out:
#      Rank CCA3     Country    Capital Continent  2022 Population  \
# 156     5  PAK    Pakistan  Islamabad      Asia        235824862
# 204    95  TJK  Tajikistan   Dushanbe      Asia          9952787
# 224    43  UZB  Uzbekistan   Tashkent      Asia         34627652
#
#      2020 Population  2015 Population  2010 Population  2000 Population  \
# 156        227196741        210969298        194454498        154369924
# 204          9543207          8524063          7621779          6272998
# 224         33526656         30949417         28614227         24925554
#
#      1990 Population  1980 Population  1970 Population  Area (kmÂ²)  \
# 156        115414069         80624057         59290872       881912
# 204          5417860          4045965          2993019       143100
# 224         20579100         15947129         12011361       447400
#
#      Density (per kmÂ²)  Growth Rate  World Population Percentage
# 156            267.4018       1.0191                         2.96
# ...

# %%
df2=df.set_index('Country')

# %%
df2_filter=df2.filter(items = ['Rank','Capital','CCA3'], axis=1)        #axis=0 for row and 1 for columns

# %%
df2_filter[df2_filter['Rank'] <= 10]
# Out:
#                Rank           Capital CCA3
# Country
# Bangladesh        8             Dhaka  BGD
# Brazil            7          Brasilia  BRA
# China             1           Beijing  CHN
# India             2         New Delhi  IND
# Indonesia         4           Jakarta  IDN
# Mexico           10       Mexico City  MEX
# Nigeria           6             Abuja  NGA
# Pakistan          5         Islamabad  PAK
# Russia            9            Moscow  RUS
# United States     3  Washington, D.C.  USA

# %%
df2.filter(items = ['United States'], axis=0)
# Out:
#                Rank CCA3           Capital      Continent  2022 Population  \
# United States     3  USA  Washington, D.C.  North America        338289857
#
#                2020 Population  2015 Population  2010 Population  \
# United States        335942003        324607776        311182845
#
#                2000 Population  1990 Population  1980 Population  \
# United States        282398554        248083732        223140018
#
#                1970 Population  Area (kmÂ²)  Density (per kmÂ²)  Growth Rate  \
# United States        200328340      9372610             36.0935       1.0038
#
#                World Population Percentage
# United States                         4.24

# %%
df2.filter(like ='United', axis=0)
# Out:
#                               Rank CCA3           Capital      Continent  \
# Country
# United Arab Emirates            97  ARE         Abu Dhabi           Asia
# United Kingdom                  21  GBR            London         Europe
# United States                    3  USA  Washington, D.C.  North America
# United States Virgin Islands   200  VIR  Charlotte Amalie  North America
#
#                               2022 Population  2020 Population  \
# Country
# United Arab Emirates                  9441129          9287289
# United Kingdom                       67508936         67059474
# United States                       338289857        335942003
# United States Virgin Islands            99465           100442
#
#                               2015 Population  2010 Population  \
# Country
# United Arab Emirates                  8916899          8481771
# United Kingdom                       65224364         62760039
# ...

# %%
df2.loc['United States']
# Out:
# Rank                                          3
# CCA3                                        USA
# Capital                        Washington, D.C.
# Continent                         North America
# 2022 Population                       338289857
# 2020 Population                       335942003
# 2015 Population                       324607776
# 2010 Population                       311182845
# 2000 Population                       282398554
# 1990 Population                       248083732
# 1980 Population                       223140018
# 1970 Population                       200328340
# Area (kmÂ²)                             9372610
# Density (per kmÂ²)                      36.0935
# Growth Rate                              1.0038
# World Population Percentage                4.24
# Name: United States, dtype: object

# %%
df2.iloc[87]
# Out:
# Rank                                       82
# CCA3                                      HTI
# Capital                        Port-au-Prince
# Continent                       North America
# 2022 Population                      11584996
# 2020 Population                      11306801
# 2015 Population                      10563757
# 2010 Population                       9842880
# 2000 Population                       8360225
# 1990 Population                       6925331
# 1980 Population                       5646676
# 1970 Population                       4680812
# Area (kmÂ²)                             27750
# Density (per kmÂ²)                   417.4773
# Growth Rate                             1.012
# World Population Percentage              0.15
# Name: Haiti, dtype: object

# %%
df
# Out:
#      Rank CCA3            Country           Capital Continent  \
# 0      36  AFG        Afghanistan             Kabul      Asia
# 1     138  ALB            Albania            Tirana    Europe
# 2      34  DZA            Algeria           Algiers    Africa
# 3     213  ASM     American Samoa         Pago Pago   Oceania
# 4     203  AND            Andorra  Andorra la Vella    Europe
# ..    ...  ...                ...               ...       ...
# 229   226  WLF  Wallis and Futuna          Mata-Utu   Oceania
# 230   172  ESH     Western Sahara         El AaiÃºn    Africa
# 231    46  YEM              Yemen             Sanaa      Asia
# 232    63  ZMB             Zambia            Lusaka    Africa
# 233    74  ZWE           Zimbabwe            Harare    Africa
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 0           41128771         38972230         33753499         28189672
# 1            2842321          2866849          2882481          2913399
# ...

# %%
df[df['Rank'] <= 10].sort_values(by = 'Rank',ascending=True) #chage True to False for dscending
# Out:
#      Rank CCA3        Country           Capital      Continent  \
# 41      1  CHN          China           Beijing           Asia
# 92      2  IND          India         New Delhi           Asia
# 221     3  USA  United States  Washington, D.C.  North America
# 93      4  IDN      Indonesia           Jakarta           Asia
# 156     5  PAK       Pakistan         Islamabad           Asia
# 149     6  NGA        Nigeria             Abuja         Africa
# 27      7  BRA         Brazil          Brasilia  South America
# 16      8  BGD     Bangladesh             Dhaka           Asia
# 171     9  RUS         Russia            Moscow         Europe
# 131    10  MEX         Mexico       Mexico City  North America
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 41        1425887337       1424929781       1393715448       1348191368
# 92        1417173173       1396387127       1322866505       1240613620
# ...

# %%
df[df['Rank'] <= 10].sort_values(by =['Country','Rank'], ascending=True)  #first one tak lead when it comes to ordering
# Out:
#      Rank CCA3        Country           Capital      Continent  \
# 16      8  BGD     Bangladesh             Dhaka           Asia
# 27      7  BRA         Brazil          Brasilia  South America
# 41      1  CHN          China           Beijing           Asia
# 92      2  IND          India         New Delhi           Asia
# 93      4  IDN      Indonesia           Jakarta           Asia
# 131    10  MEX         Mexico       Mexico City  North America
# 149     6  NGA        Nigeria             Abuja         Africa
# 156     5  PAK       Pakistan         Islamabad           Asia
# 171     9  RUS         Russia            Moscow         Europe
# 221     3  USA  United States  Washington, D.C.  North America
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 16         171186372        167420951        157830000        148391139
# 27         215313498        213196304        205188205        196353492
# ...

# %%
df[df['Rank'] <= 10].sort_values(by =['Continent','Country'] , ascending=[False,True])
# Out:
#      Rank CCA3        Country           Capital      Continent  \
# 27      7  BRA         Brazil          Brasilia  South America
# 131    10  MEX         Mexico       Mexico City  North America
# 221     3  USA  United States  Washington, D.C.  North America
# 171     9  RUS         Russia            Moscow         Europe
# 16      8  BGD     Bangladesh             Dhaka           Asia
# 41      1  CHN          China           Beijing           Asia
# 92      2  IND          India         New Delhi           Asia
# 93      4  IDN      Indonesia           Jakarta           Asia
# 156     5  PAK       Pakistan         Islamabad           Asia
# 149     6  NGA        Nigeria             Abuja         Africa
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 27         215313498        213196304        205188205        196353492
# 131        127504125        125998302        120149897        112532401
# ...
